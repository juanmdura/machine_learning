# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import math

# %%
def predict_using_sklean():
    df = pd.read_csv("test_scores.csv")
    r = LinearRegression()
    r.fit(df[['math']],df.cs)
    return r.coef_, r.intercept_

# %%
# %matplotlib inline

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 100000
    n = len(x)
    learning_rate = 0.0002

    plt.scatter(x, y, color='red',marker='+',linewidth=5)    

    cost_previous = 0
    
    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        
        plt.plot(x,y_predicted,color='green')
        
        cost = (1/n) * sum([val **2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2 / n) * sum(y - y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd

        print("cost_previous {}, cost {}".format(cost, cost_previous))
        
        if math.isclose(cost, cost_previous, rel_tol=1e-6):
            print("REACHED WITH {} vs {}".format(cost, cost_previous))
            break
        cost_previous = cost      
        
    return m_curr, b_curr

# %%
df = pd.read_csv('test_scores.csv')
df

x = np.array(df.math)
y = np.array(df.cs)

# %%
m, b = gradient_descent(x,y)
print("Using gradient descent function: Coef {} Intercept {}".format(m, b))
# Out:
# cost_previous 5199.1, cost 0
# cost_previous 4161.482445460163, cost 5199.1
# cost_previous 3332.2237319269248, cost 4161.482445460163
# cost_previous 2669.4843523161976, cost 3332.2237319269248
# cost_previous 2139.826383775145, cost 2669.4843523161976
# cost_previous 1716.5264071567592, cost 2139.826383775145
# cost_previous 1378.2272007804495, cost 1716.5264071567592
# cost_previous 1107.8601808918404, cost 1378.2272007804495
# cost_previous 891.7842215178443, cost 1107.8601808918404
# cost_previous 719.0974036421305, cost 891.7842215178443
# cost_previous 581.0869686205, cost 719.0974036421305
# cost_previous 470.7897237271261, cost 581.0869686205
# cost_previous 382.6407204862143, cost 470.7897237271261
# cost_previous 312.1924801681589, cost 382.6407204862143
# cost_previous 255.89060022344475, cost 312.1924801681589
# cost_previous 210.89442007737276, cost 255.89060022344475
# cost_previous 174.93369813849728, cost 210.89442007737276
# cost_previous 146.19406878727372, cost 174.93369813849728
# cost_previous 123.2255001796068, cost 146.19406878727372
# cost_previous 104.86913418555842, cost 123.2255001796068
# cost_previous 90.1988172376793, cost 104.86913418555842
# cost_previous 78.4743720801518, cost 90.1988172376793
# cost_previous 69.10425278659366, cost 78.4743720801518
# cost_previous 61.61569883880534, cost 69.10425278659366
# cost_previous 55.63088241716976, cost 61.61569883880534
# cost_previous 50.84784543555072, cost 55.63088241716976
# cost_previous 47.02526451581355, cost 50.84784543555072
# cost_previous 43.970275232370476, cost 47.02526451581355
# cost_previous 41.528741309884765, cost 43.970275232370476
# cost_previous 39.57747781519814, cost 41.528741309884765
# cost_previous 38.01803597157669, cost 39.57747781519814
# cost_previous 36.77173601363096, cost 38.01803597157669
# cost_previous 35.775697470042715, cost 36.77173601363096
# cost_previous 34.97966658555935, cost 35.775697470042715
# cost_previous 34.34348081266759, cost 34.97966658555935
# cost_previous 33.83504244613808, cost 34.34348081266759
# cost_previous 33.42869916198312, cost 33.83504244613808
# cost_previous 33.103949752366304, cost 33.42869916198312
# cost_previous 32.84440975547639, cost 33.103949752366304
# cost_previous 32.636984792143764, cost 32.84440975547639
# cost_previous 32.47120990063734, cost 32.636984792143764
# cost_previous 32.33872153636954, cost 32.47120990063734
# cost_previous 32.23283559672576, cost 32.33872153636954
# cost_previous 32.14821018063812, cost 32.23283559672576
# cost_previous 32.08057606773955, cost 32.14821018063812
# cost_previous 32.02652131866401, cost 32.08057606773955
# cost_previous 31.983319128693804, cost 32.02652131866401
# cost_previous 31.94879024926364, cost 31.983319128693804
# cost_previous 31.921193035921274, cost 31.94879024926364
# cost_previous 31.899135575212195, cost 31.921193035921274
# cost_previous 31.881505456930224, cost 31.899135575212195
# cost_previous 31.86741364845402, cost 31.881505456930224
# cost_previous 31.85614963940047, cost 31.86741364845402
# cost_previous 31.847145593458148, cost 31.85614963940047
# cost_previous 31.839947698713402, cost 31.847145593458148
# cost_previous 31.83419327097573, cost 31.839947698713402
# cost_previous 31.829592454870966, cost 31.83419327097573
# cost_previous 31.825913599447194, cost 31.829592454870966
# cost_previous 31.82297157043309, cost 31.825913599447194
# cost_previous 31.82061840945363, cost 31.82297157043309
# cost_previous 31.81873586892226, cost 31.82061840945363
# cost_previous 31.81722944596486, cost 31.81873586892226
# cost_previous 31.816023614361388, cost 31.81722944596486
# cost_previous 31.81505801393808, cost 31.816023614361388
# cost_previous 31.81428440514876, cost 31.81505801393808
# cost_previous 31.81366423519171, cost 31.81428440514876
# cost_previous 31.813166692862268, cost 31.81366423519171
# cost_previous 31.812767154001268, cost 31.813166692862268
# cost_previous 31.812445939105075, cost 31.812767154001268
# cost_previous 31.81218732041362, cost 31.812445939105075
# cost_previous 31.811978728380467, cost 31.81218732041362
# cost_previous 31.81181011748764, cost 31.811978728380467
# cost_previous 31.811673459407757, cost 31.81181011748764
# cost_previous 31.811562337942128, cost 31.811673459407757
# cost_previous 31.811471625297237, cost 31.811562337942128
# cost_previous 31.811397223366267, cost 31.811471625297237
# cost_previous 31.811335856963026, cost 31.811397223366267
# cost_previous 31.811284908575193, cost 31.811335856963026
# cost_previous 31.811242286300104, cost 31.811284908575193
# cost_previous 31.811206318299767, cost 31.811242286300104
# cost_previous 31.811175668449643, cost 31.811206318299767
# REACHED WITH 31.811175668449643 vs 31.811206318299767
# Using gradient descent function: Coef 1.044623042451559 Intercept 0.018272090759846052

# %%
m_sklearn, b_sklearn = predict_using_sklean()
print("Using sklearn: Coef {} Intercept {}".format(m_sklearn,b_sklearn))
# Out:
# Using sklearn: Coef [1.01773624] Intercept 1.9152193111568891
